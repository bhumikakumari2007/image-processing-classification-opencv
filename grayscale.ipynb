# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(r"C:/Users/priya/Downloads/WhatsApp Image 2026-05-20 at 2.30.48 PM.jpeg")

if image is None:
    print("Error: Image not found. Check the file path.")
else:
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    plt.imshow(gray_image,cmap='gray')
    plt.axis('off')
    plt.show()

# %%
#Grayscale

# %%
Grayscale conversion is used to simplify an image by converting it into shades of gray. It removes color information and keeps only intensity, making it easier to process and analyze images for classification.
